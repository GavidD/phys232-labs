# %% [markdown]
# # <div style="background-color:rgba(204, 229, 255, 0.5); text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px"><span style="color:rgba(0, 76, 153, 1);">PHYS 232 - TEMPLATE<span style="color:red"></span></span></div>

# %%
# Hide unnecessary warnings.
import warnings
warnings.filterwarnings('ignore')

# Add paths to find PHYS231
import sys
sys.path.insert(0, '..')
sys.path.insert(0, '/home/jovyan/PHYS232')  # UBC JupyterLab path
sys.path.insert(0, 'C:\\Users\\gdoer\\Documents\\Github Repos\\phys232-labs')  # Windows path

# Import PHYS231 and run the installer
import PHYS231
PHYS231.Installer()
# Out:
# <text style=color:black>All packages already installed. Please proceed.</text>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm 
import pandas as pd
import scipy.stats as sp
from scipy.optimize import curve_fit
from IPython.display import HTML as html_print
from IPython.display import display, Markdown, Latex
import uncertainties
import math
import sys
import os
os.chdir("/home/jovyan/PHYS232/Brownian_Motion") #### SET THIS TO CORRECT PATH

# %%
PHYS231.Scatter(
    xData = ,
    yData = ,
    xlabel = ,
    ylabel = ,
    xUnits = ,
    yUnits = 
);
# Out:
#   Cell In[65], line 2
#     xData = ,
#     ^
# SyntaxError: expected argument value expression

# %%
m, b, dm, db, fig3 = PHYS231.LinearFit(
    xData = ,
    yData = ,
    xlabel = ,
    ylabel = ,
    xUnits = ,
    yUnits = 
);
# Out:
#   Cell In[66], line 2
#     xData = ,
#     ^
# SyntaxError: expected argument value expression

# %%
# ==== Notebook setup: Python and NumPy basics ====

for i in range(10):
    ...


a = np.array([1, 2, 3])
z = np.zeros(10)
o = np.ones(10)
t = np.linspace(0, 1, 100)

b = 2*a + 1
c = a**2
s = np.sin(t)

a, a[-1]
a[1:4]
a[a > 0.5]

a.mean()
a.std()
np.sum(a)
np.cumsum(a)
# Out:
# array([1, 3, 6])
